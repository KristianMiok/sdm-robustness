# %% [markdown]
# # Inspect master table
#
# Quick sanity checks on `combined_data_true_master.csv` before running Task 1.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from sdm_robustness.io import load_master_table, get_predictor_columns
from sdm_robustness.utils import setup_logging

setup_logging()
df, info = load_master_table()
print(info)

# %%
# Predictor column counts
cols = get_predictor_columns(df)
for key, vals in cols.items():
    print(f'{key}: {len(vals)}')

# %%
# Top 10 species by raw record count
df['Crayfish_scientific_name'].value_counts().head(10)

# %%
# Distance distribution among High-accuracy records
ha = df[df['Accuracy'] == 'High']
ha['distance_m'].describe()
